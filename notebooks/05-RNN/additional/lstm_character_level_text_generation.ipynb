# %% [markdown]
# # Character-level text generation with LSTM
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/15<br>
# **Last modified:** 2020/04/30<br>
# **Description:** Generate text from Nietzsche's writings with a character-level LSTM.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to use a LSTM model to generate
# text character-by-character.
#
# At least 20 epochs are required before the generated text
# starts sounding locally coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %% [markdown]
# ## Setup

# %%
import keras
from keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Prepare the data

# %%
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 1s 1us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Prepare the text sampling function

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# 1565/1565 [==============================] - 11s 5ms/step - loss: 1.9716
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "hilosophy is a proof of the superior tru"
# ...Generated:  th the stands and in the self the self and it is the self the self it is the self and the self the self in the preasent in the says the self and so the sense of the self the self the self in the self the self the sense of the self the sense of the self and and and and it is the self and preasent and the self the man in the self the experience and stands it is the self the self and so the self in t
# -
# ...Diversity: 0.5
# ...Generating with seed: "hilosophy is a proof of the superior tru"
# ...Generated:  st of the self in the saint in they be the sperse of the our all the self the preasent and not it is the soul and appeated the dearted one suspivity in the man and a science, and and also the have it is the hearth of the ore man is the preasure and as the sciences of the self suppect of morals of the understing in the sand strong senved the hard consiter, so the man and a periase of the philosophy
# -
# ...Diversity: 1.0
# ...Generating with seed: "hilosophy is a proof of the superior tru"
# ...Generated:  atifitions -an all take out and "the imour the cherines they agnaate is at grangance, in allo that have whish fremically reading not what in on all vears, in more.  -lo soull forsilaty head ulvondally that it is æith, whoneit and their conners modaments, has hor serious forchively the have a old thos lives livet. ;ëo found the ssuel than exted, shish meant is relioting whe e feelitation on all thi
# -
# ...Diversity: 1.2
# ...Generating with seed: "hilosophy is a proof of the superior tru"
# ...Generated:  menat wound in sham3nother, the sequrat:" enogants. "holl. whap]kand murnce, may beens grextmuations, and his freeth then, is creation=iiny, pirit, ot ywo! of conutraminy, oncilt abst rehaistly powlaytiands hescteviou hangred; meay actnow, with cuctuned of the sopporedentedodctomething--so scaphishing of chyindisa the5ing, geers re"knession orker own, but wasl: so that in, bum even is, oven is nef
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.5926
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "hall be the greatest who can be the most"
# ...Generated:   desire of the such a still to the standands of the result of the perhaps the stance the dection of the soul of the streeds and all the former and and all the such a conscious of the streeds of the conscient of the moral the stated the standard to the moral the stated the discover and in the moral in the destinct of the destinct of the sense that it is the something the stance of the strength to b
# -
# ...Diversity: 0.5
# ...Generating with seed: "hall be the greatest who can be the most"
# ...Generated:   such distance essenties of gaise in the subclase of the too will has such philosophers in the ending in this litter something sense of the  marsely and last dece of life if the such a believe the light far the there is not in feeling will to general the decisime there is the streeds and the scientific of all the one for in the will eneraphers of deduced, and really that the soughon in the light o
# -
# ...Diversity: 1.0
# ...Generating with seed: "hall be the greatest who can be the most"
# ...Generated:   laws (we wall wither marked, such has contray. cause.  vair couracisance are cruced into thatured welious tas pores a truthly unestration of man be thisely the retaphise to acts refiriness oftens enument through be realing wull which and prode pleis1, the ouble. and stronge easipera-.and to deally from the not and decives itselfss imkear gaites coltung8 photerid menizaraus", gresching wavely do t
# -
# ...Diversity: 1.2
# ...Generating with seed: "hall be the greatest who can be the most"
# ...Generated:   in4thity,"" even nor has indeens of incourigily, in chinkic,,es, in voss even as "impaw rebest? this aller"--=deed, =phirour enmsevancal mot whenbwardæf-symparkanceos). also kevow w5 retains religtor" ampotress him, usunted, or defferem:-, as thosect honew. every progratingly im, in aresest contunus]; wheref in cumplusiw thought, un.", ungoance." adouthoun." i yould will is the banys and  might c
# -
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4906
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "ual intercourse will cause the imaginati"
# ...Generated:  on of the species of the same sident of the such a subjection of the subtle the such a sur still the subtle the contrary in the contrary in the subering and subjection of the substance, with the same strange of the soul in the contrary of the say, a subtle in the present and a cannot the subtle and an inclusition of the contrary in the same time the contraring to the individual and fact of the sub
# -
# ...Diversity: 0.5
# ...Generating with seed: "ual intercourse will cause the imaginati"
# ...Generated:  on of a a factition of a still that precised in the same faction of morality of themselves presentical and something to their cape, of morality and presiber and the contention of pranged and the will us to the sudfly of strongly a greeks and he is in their bad out of the himself and a that and religion of which they it is not be to have the considerable and such a concernion of the presenticism an
# -
# ...Diversity: 1.0
# ...Generating with seed: "ual intercourse will cause the imaginati"
# ...Generated:  on of leagning ind the in historician to them or time in thew flow certain discipring their pretucion and whole in sense their shound the yperkly again them in thereby nated; religion of their badry, and condedit of ithers of such a facthou nogling even in in hin with their observed that of the ideap" at found of so delicate of revenves. on, in as one grounification, i strong to usterpionce of man
# -
# ...Diversity: 1.2
# ...Generating with seed: "ual intercourse will cause the imaginati"
# ...Generated:  ne out that, those of curarvulth: oh any sacit oithinadrche out moral experience and of dif human concelt, new suqued being, li entibles. usentialction;. "   1p  are hamames of all purposing mores in humanidiys--is there in undess, no leapte  un, of time halp nally urough of senvem: that be inhurial, puttrication of lexs enticleberination streede in genoughly frona:-not suchonal enomphs. they, mor
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4385
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: " being who often runs away from himself,"
# ...Generated:   and the present and its consciently and the propering to the powerful to the as a standing to the present as the soul and the sacrificed and it is not the comman, and the stands and a standing to the present that the an and the are and the as the world, and the present and a socied of the and and of the soul and an and the such a things and the sacrifice and an an all the properities of the soul
# -
# ...Diversity: 0.5
# ...Generating with seed: " being who often runs away from himself,"
# ...Generated:   that the graining to the uncertanter, and it is not the sense, and first and not and everything to the conscience whatever in the asperfice is properion of the such distrest that he there is there is no of the their such presential to reading of the contradical consciently in the grains of the world, and often have all face, it is proper and strengtions in the great life that the artification, ma
# -
# ...Diversity: 1.0
# ...Generating with seed: " being who often runs away from himself,"
# ...Generated:   of behuthers in these forght," if pointing; a gettrination of sacrilizes, firness, oser sterking to a trainer--who is. to his own such like them, in the hthes.      a than cirslains, than so to conception whone_ thatool there may that this comnans heagh be trufgest to gover. is if there is or ascalled, the rease to a crristinal judgment as for had to elseding than thriunds and god amo, hacling of
# -
# ...Diversity: 1.2
# ...Generating with seed: " being who often runs away from himself,"
# ...Generated:   with rightly asseration if morally motterfeptiess, the ordical mentlion" coubhow, mapelly to the germar. this systems, an un.  13ec whichly concirme?--this viltly: the stick, someww inatertit. as enignasantant. he crie if nopirs-nehins childr distract to erse permpate like must as their other,--parres.  senses who ariss--the taste attaining thdived that we for the own bedoencise, non bespekn was
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4051
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "r great things, looks upon every one who"
# ...Generated:   is the philosophy of the same the subpriticess of the sensation of the subtinal the problem of the loved the present such a strange the man in the sensation of the surprises and the subting the subtlety of the philosophy are the world of the readly the same things the sensation of the subtlety of the sensation of the subting the sensation of the sensation of the sensation of the sensation of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "r great things, looks upon every one who"
# ...Generated:  m is also themselves in the loged in sought of the such a man of the interpretation of the sensation of self the philosophy, there is not we should in race without be itself in the self-destraintism of all power--i
# -
# ...Diversity: 1.0
# ...Generating with seed: "r great things, looks upon every one who"
# ...Generated:   indeed natuing such deses this living may utilitars in accession obtil, os the things hitherto as then also a glown wearness must desires then they will forcusias that they haveselfles, but they of concerners still instinctive are surcepedomed and learn them are consensates in at this buluncie of the like is "getsion have not they easier out of degeneration. mere learn, supply ans otherdfomedy an
# -
# ...Diversity: 1.2
# ...Generating with seed: "r great things, looks upon every one who"
# ...Generated:  men had being buty.-5y. ?han prilofatianing, cley undur, been not at altitect men allow and does you him the philosopher, in irder nears of womkn"v--as they very would see; as a subtle itrevance, for comprehensias, the, them year bad ourselvess, it is a grutashyph into other way us spey go--our causpom from feetingshing[ness., should ford," they have they falcing" admioudlys. superteden no esuepte
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3822
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "oint in every philosophy at which the "c"
# ...Generated:  onsequence and an and and entire the sense of the things and an an and the sense of the sense of the sense of the sense of the sant of the respect of the state of the process and far and instinct and an and one of the fact the possible to the sense of the sense of the supposed and the conception of the sense of the sense of the standary of the strength of the state of the so the more the strange o
# -
# ...Diversity: 0.5
# ...Generating with seed: "oint in every philosophy at which the "c"
# ...Generated:  reatic a moral by the not without all and after the one in a morals in the world of a feeling of the philosoph, has a man as a consequence and a fact than the more perhaps and our still strength of the an and freedom of the portratic of our and from the more call father of the suppose the last a moral and us of all the state of the modere--a such a philosopher has been believe the power of the sen
# -
# ...Diversity: 1.0
# ...Generating with seed: "oint in every philosophy at which the "c"
# ...Generated:  ase is the reasonius into moral everyable for kjod lights of convensed cruall three mast! have still who in the world without refutite handen that nobeded are a pains. one's repretained by standable tanned parnt--mudiffel. every one dordoroes acrorked probous out of the ruly with nor wil") good and entlited orportfuln heal nobele sacrifice wh he clast princapal fath apos. "indeced master on the cp
# -
# ...Diversity: 1.2
# ...Generating with seed: "oint in every philosophy at which the "c"
# ...Generated:  ripporory back, that century make--dance--wishes nobse i reciss, for, vound easies, "noal and exteebled abovied.  152. tham circumstances apo su, and pot 'pore spir(tate, at it were as the men of dilcape, it hand in ute inflacsibl,! vertutagm of the so from and philosoph out of can gilen moxettyphay to become thmir actname sapeates injury is pithelents and matable globlionved in threate, while con
# -
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3633
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: " best be arrived at and some compromise "
# ...Generated:  the subtle in the spirit to the such a strange the sense of the sense of the such a sense the sense the soul to the problem of the self-such a serious and the sense and soul and soul and soul and self-sense to say, to the sense, and the sense of the the sense and soul in the same stronger and self-such a soul it is the sense the sense of the sense the sense and the sense of the same such a sense a
# -
# ...Diversity: 0.5
# ...Generating with seed: " best be arrived at and some compromise "
# ...Generated:  of the sense of seeming and "suffering man and all this again the soul who would fact the sense of such soul may be the latter as the fact that it does to purion to the soul so soul specially and the result of which the ascertain the importing as so fact their life and self-dearting, the word to power and powers they hater suffering to dood in the things and self such a transfection to such a seem
# -
# ...Diversity: 1.0
# ...Generating with seed: " best be arrived at and some compromise "
# ...Generated:  of the value time buerchern to befote nobination and terik. if certain god" a "teith there is not so prabsepounting time with their freenseacity and edeal, schopenhauer, as the act awon, the astimens, should power, when a short, he shall than sep surmer then contin a out in orderly, ner philonome, bean agreate. this not endurate do. this aggerial daying himself, portrent ourselves, sympathy, sensi
# -
# ...Diversity: 1.2
# ...Generating with seed: " best be arrived at and some compromise "
# ...Generated:  laugh offering that no pherimanwave regodlod again that "such deaundedbitting until skinul behthering, there are casist. there is rulizing ehmbinishnatation of make. that they net iusal must they care all twioul cannationally is itself ot belong to as noting his "man are ngers theus errorsibly retime not as"itness indicced; self-soeth foranded triatic recoveralible fish my conduct," they wand hims
# -
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3499
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "tain german potency and super-plenitude "
# ...Generated:  of the standard the process to the desire and appearating of the more processed and the standard to the state of the stare and as the processes the ambody and the state of the stare of the standard to the instinctive and the old as a standard and standard to the state of the standard and a standard and stare and processes of the action of the process to the standard to the same time the stand and
# -
# ...Diversity: 0.5
# ...Generating with seed: "tain german potency and super-plenitude "
# ...Generated:  and far and concealed in the preserve and that a standard to sacrifice in all fact the mastery of the amountion of the self-rener of the relation is a reclise to the lives the individual the mastery and possible of the first and such a with the conduct man, so depender to the other distinction and sympathy that the children of the self-distance of the conditional and the must not to the still to b
# -
# ...Diversity: 1.0
# ...Generating with seed: "tain german potency and super-plenitude "
# ...Generated:  basis as, the psycholobopiant excessities of the philosophy ray--possion: feam, that we prokinge, what every colalt when he faptarie for whom the saint of what almost ludul mispowebly in it who be the prime pitutuee, appearable! but with laftorold of humanity awameing masses to the made for scording foreow. it regarding the capous their much of all some2ging to philosophical wholy were first at fu
# -
# ...Diversity: 1.2
# ...Generating with seed: "tain german potency and super-plenitude "
# ...Generated:  anely asmaning, feould8y, at as hholarsing." and strong, fundamentally," "the raped as lateft that: biste.  80  i the recking granturo-efucrem: and its deceesept, productout9ted, and fashiol of synthem has cuanius lajling neth to thest free y-and would centiousy rather homous mare that, or, over m: to us tant reedly image two not flamsour ye knows amam)ileoms are exterrals.   =3 "wit inele word,"
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3366
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "! how the noblest and the commonest stan"
# ...Generated:  ds and and and the state of and and in the strength of the contrary the stands in any present the desire to singless and extrained to the stand of the spirituales and in the problem of the state of the stands in the conceited and in the state of the contrary the soul of the stands in the sense of the stands and in the states of the stands and the stands the strength of morals and destruction of th
# -
# ...Diversity: 0.5
# ...Generating with seed: "! how the noblest and the commonest stan"
# ...Generated:  dard with the sense of the instinct of the life the contrary and and does not in its perhaps in an respect to the soul for his inunverstrocrical sentiments of distrust of the lessing the contemplation of conscience that who are existence of insising and conscience in the master, and immoralls in any prichan so does not and more than in the procour of morals it is an instance, the whole conscience
# -
# ...Diversity: 1.0
# ...Generating with seed: "! how the noblest and the commonest stan"
# ...Generated:  dards (thir love it seem of these lives require of the iy morality of control glorially sympathy.   8ë  =sort, but the sens--that how single even that work and interest incertmined presanterings of morality he for a lapses of one no1s by, the phe, another with their  are phase morearility of refined conleasure spirituened; this master still an e spel senoring, for thly we or the result, simblectat
# -
# ...Diversity: 1.2
# ...Generating with seed: "! how the noblest and the commonest stan"
# ...Generated:  ds in generally remilities spohded--allly the moteriat world grast dealine erb). thmoud ofto, kniw in all defort with a vention palop: eye of aute-thery conneleled he willingwment in evident selze framity--nature with all rdentslibandits. herese.--let himself, which all t0ken they nopic establisheness willlenoho-bitnces, or four first bicknw with destinyterming other the anduorys strangewthan--the
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3257
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "le to injure a powerful enemy by means o"
# ...Generated:  f the same strength to the sense--all the same world and in the condition of the conditions of the restinged to the restinged and the strange to the stronger to the problem of the philosophy and the senses of the problem of the strength to the sense of the world and the strange come to the sense of the sense--all the sense of the same time to the same time the same possible and all the same time t
# -
# ...Diversity: 0.5
# ...Generating with seed: "le to injure a powerful enemy by means o"
# ...Generated:  f a philosophy in such limited in regard to the soul to self conceptions to the soul to an appear and well with some moral constant and the later conscience the same time with a standing end of the art of the substates and said, all first the genius, it is the men of the substate of the case of all thinking one as still under the spectative on understood, it is the advance of the bad of the powerf
# -
# ...Diversity: 1.0
# ...Generating with seed: "le to injure a powerful enemy by means o"
# ...Generated:  f mankind--on a people he regarding he stalf--a relation of the states, as it is not considence through commonar laught dissime cutse, been that cause a alone and its condition, which is really all discreited as a people are the same othersion far waszen to be strenk-nceival to our dangerous friend term) to night. in itatly a fearcipe also come called all laffind--happect to the histor moral of th
# -
# ...Diversity: 1.2
# ...Generating with seed: "le to injure a powerful enemy by means o"
# ...Generated:  f reachy indeed to yet former pyre ds, "woman" "will, and come of no reasons age staphes or traced for erstricp, slay--indoidorativew nature. forth-(antage evilst bad mankind. there, obsestion," i cirmanally thcture, soat no german we darely evilsthilist lyted womanne than no extent this advantest and that diide sake pares, in markin" the worthn0 as thing; all that ims: proceent him was own becaus
# -
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3170
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "immediately.  139. in revenge and in lov"
# ...Generated:  e and the world and the soul, the same world of the subtleiss and streach is the sort of the subtleity and an action the specially and so the world, and the same truth and the world, they are and so the world, in the soul of the process and woman in the soul of the seems to the world, and the specially a stronged to the bad and conception, and the same world and present to the same world and conce
# -
# ...Diversity: 0.5
# ...Generating with seed: "immediately.  139. in revenge and in lov"
# ...Generated:  e and calcule and bad discosrained the have a so that it will a personal consist as i see the reason the sould the profoundly we are as the fact that which is a soul--as the same things for the strange to a man of the impulse of the contrary in the profest and desirable of the more plations to the same thing they may not be read in the reason that is a man is the certain in the philosopher is the
# -
# ...Diversity: 1.0
# ...Generating with seed: "immediately.  139. in revenge and in lov"
# ...Generated:  e!" in the world, and not involuntary to be magrounding only bad what are to be regurated and reals for what is not bad and phish and not human stray and evil of circe, is many didly yet: mechaish at the worlds myself and then, such that in convient only view. but we extempthing; i shall as the same delight to the years which that, only colcrees bure than that with nocashedinary beyond "art, subtl
# -
# ...Diversity: 1.2
# ...Generating with seed: "immediately.  139. in revenge and in lov"
# ...Generated:  e-eiom for negation that itself only away a tradibillabilatives thest of them to ever ur. life natuesfactor!  xqu. aswelson even hatrigicias that there is many proxhiface äsbelition lastical prelightf, the compliceted caract, transible eagroff, for him the sureshity of the that hrenciors to learn, i reason her daid yet in grawn natureal, knowledge hacce or absolutely beaubed or of ou, that they be
# -
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3086
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: " mirroring and eternally self-polishing "
# ...Generated:  and in the self-decisous of the most self-desire the continues of the continues of the prount the ordal to the most desire the most self-desire the morality of the self-destrained the most serve, there is there is there is a self-desire that the most self-desire and probably and in the self-desire the serious and in the same thing that the one the self-desire to the most desire to the most self-de
# -
# ...Diversity: 0.5
# ...Generating with seed: " mirroring and eternally self-polishing "
# ...Generated:  it will all only the serious and fortuality in a man and every still at all the light to the fortuine of all famining in the sense, probably man in the stalistical concerner in their light to the belief seeks selfing out of the resenting to the physiology of merely the belief of the apparent of the hereditarily, it is only there is a morality in the world of an its adverent and in everywhickent, a
# -
# ...Diversity: 1.0
# ...Generating with seed: " mirroring and eternally self-polishing "
# ...Generated:  which is there mean the cot of the angers there is, no longer remotrect--no strict of trace and have alekemhing as so a dealtness, is his virtain the riroposness--alcouning,! quise that in equal to precisely theher only their world-resingo. make almost that that simply how be mastery which retaries. according what is tonshat that is, that there that nowadays and act under the real fast in the puls
# -
# ...Diversity: 1.2
# ...Generating with seed: " mirroring and eternally self-polishing "
# ...Generated:  at all ofgnevest achsigness?--    is who uhseuven of preters of bestoking of rule, that connective glers, "when i.  upe]--nample, howilest one moral presedive.z.   141  =mora, pauth men of if ups god everything in that exaltenments at hers of other place siine it? , fively in their truth, as skird or thus almort always by thisicce, that his liver--unings foct thed that who was mode, that noble the
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3026
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "e books, are in the habit at present of "
# ...Generated:  the interprete and and the sacrifice to the same time the same time the same to the same that in the sense of the same of the same to the same time to the same standing to the same time that is a subjection of the same time the same things and and the same things and such a consequently the same taste of the same of a strength of the same to the saint of the same time the same time that is not and
# -
# ...Diversity: 0.5
# ...Generating with seed: "e books, are in the habit at present of "
# ...Generated:  the rest be the moral cause and and cause and much and ideal constitute of the condicity and at the say! the most sacrifices to be its supposing nature to ourselve in the contrary of the interpreted and and his standard of supposing in any krence in the subject and man state and he would contempled, the strength of morals the presenting to the powerful and the development of self and withine stupr
# -
# ...Diversity: 1.0
# ...Generating with seed: "e books, are in the habit at present of "
# ...Generated:  to langest too recorition of this entires at knecty wishes corceptain state as far in bignt "either, and is morals as cerpoct every ven in developtibly supposing them, there enough, is in condiculans are bindless, it remarkness and existed, supposing of opport of the most hand been if certain ul entire says being sailtisour and early, they like rance far as is not practice. it is extent i farunshi
# -
# ...Diversity: 1.2
# ...Generating with seed: "e books, are in the habit at present of "
# ...Generated:  one-wigh alligitude; otherwise, not say that.   114  =pedlewptors that is like one happen, in the  neares can no viring. so ard very so have a rellogition (ant equutial of the first. he do right in emotede slorin revenge peows, not much forthes clumblistion accompth wherew oncenours: with it is may hevent: in a glexibiticuespo, is perhaps nurlided, it is advantury would a defenct does as ourzing o
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2963
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "always paradise": so say the most ancien"
# ...Generated:  t desire the personal the sense of the sentiment of the sense of the sense of the sense of the sentiments and conception the conception the contrary the standard and belongs in the sentiments and sense and partice and experience and the sentiments and sense of the same with the self-desire the sentiments and and sense and as the sentiments and and the sentiments and the sentiments and sense of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "always paradise": so say the most ancien"
# ...Generated:  t the philosophy, and and and such disinside the and self-deceptions are the things of a perpociation of the best by the stances accurtate and profoundly in their interporing with every concern the last side of the subtlery and accuration to loodow--a denection to mankind interprete the ambody and conception to well the arring and sense they are the personalise manifests and belongs in the philoso
# -
# ...Diversity: 1.0
# ...Generating with seed: "always paradise": so say the most ancien"
# ...Generated:  tly, begay nowaday?--to say, they indismuth. they wosker?" when there is it is farsely and missay upers auther laebly receives of the other willings.'s it has soent are manni1naring, and with conduct, every agains, a creatice there is presamen or of3e the ward the heriking, so therebymeness is favour-german e"parences, naelqueshes in things--respect to him and moges of are things things, and insis
# -
# ...Diversity: 1.2
# ...Generating with seed: "always paradise": so say the most ancien"
# ...Generated:  ce diepts well from those compulsors of screaps an average with these hyt a little concerned with a perficing ease orreously?.--the customained (faphled up- theo mary recealite one's world agrerceonos! for i haur sourtled distinctood has not conceptingmous enaugate ludname" have no mores this comption, aid no other--but grane with woster achryponed, sense to hoide. how and yet they are greatesn in
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2913
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "nce and the thing-in-itself seem to it s"
# ...Generated:  uch a strength of the most superstorany and superiority of the superficial to the most sentence of the present the superstition of the subtle in the fact that the superstition of the highest and self-contradiction of the superficial to the subtle to the sense of the fact that the same things and as the superstition of the subtle is the superstition of the subtle to the same truthful, and the spiri
# -
# ...Diversity: 0.5
# ...Generating with seed: "nce and the thing-in-itself seem to it s"
# ...Generated:  uch a distrust of christianity that the saints and last will to the strange and as it is the moral of the virtue of superslang and who is the love of the present that is the subtle and self-partical it and religious problem of whom find the heart of all this is it will the worst what the raged to so regard the moral the world, that it is passion that the surpactive the heart of the strength and th
# -
# ...Diversity: 1.0
# ...Generating with seed: "nce and the thing-in-itself seem to it s"
# ...Generated:  elf-arout: a luse remostful rshesexply mean? by the other "nobling, reawing however, in value on one down of apvilitar to use or an interrosertly esteep of envyparasion, in which he from the spiriture? afull inward, and have always be humanity to practiced, divine. that will as i truthly than "have that it is asking spiritual eormem is it!  there is also him of woman a life above ethic time. a act
# -
# ...Diversity: 1.2
# ...Generating with seed: "nce and the thing-in-itself seem to it s"
# ...Generated:  uwpley; on time."  the oldly rassh wrongs, one easior and upon the race, we only through ill was could slave himso offfully dalso with friend,   there have reacrying; as or the only which af vessualest will understane from soeth: it is once if cleasually mairteral--is heart when thy no exhiben of biddal pic: i think, it named deprihes terffet goodness of to use mapes, which hempodome" afulless has
# -
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2856
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: " existence of an individual: [in order t"
# ...Generated:  o the most point of the morality and who has a power and and respect to the sense of the thing is the power as the subtlety of the extraved to the sense of the philosophy of the problemine of the sense of the power and as a power and and more from the world and and sensible to the thing in the subtlety of the considers and and and and conscience and case which is a stronger and the thing in the pr
# -
# ...Diversity: 0.5
# ...Generating with seed: " existence of an individual: [in order t"
# ...Generated:  o generation the ends consequently sensible, like the power and the wield sin of the power in the higher and above all the same with find to the senses of a self-deep to the "sympather and things who in the deeper of problemical in an are the sign of the sensible in a self-distrust of boots the truths the more self-determined to simply the tenement of the reason the substant of succamistion and so
# -
# ...Diversity: 1.0
# ...Generating with seed: " existence of an individual: [in order t"
# ...Generated:  ofooled in all udaticians. when we prepauntian there say to what they it afwame the "oeting pange, as sompturance of imporvers of prover deat that is mous more origor as sought forthous consequently been mantiolous exhible the and apes has surtaifing should been of the passi is the teach invident to passion of vicerous same picrising, mache in the "god"ty, why homething why must? rightly no lowe r
# -
# ...Diversity: 1.2
# ...Generating with seed: " existence of an individual: [in order t"
# ...Generated:  o chircimisors slew notion of feel not before moral a convent? as the blood. when he is couring and freatus things than it becomes to obeyent is owqyes do the facce, ridor into beare it wile vicite of which neevowly and, which were air inm-cauthsiandand ismuet philosophy still longouses to life, but phre the ejoking mounds" of comingry, alsowascy: "not a surpen troubten signiance that every ones l
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2822
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "ce, messrs loafers and cobweb-spinners o"
# ...Generated:  f the self-destructive and an experienced the protested to the standards of the problem of the more the sentiment of the subtle, and the standards and self-distrust of the most supposition of the problem of the superioratives and as the supposition of the superioration of the same the state of the streath the higher the prored to the standards and the protested to the standards and and an extend o
# -
# ...Diversity: 0.5
# ...Generating with seed: "ce, messrs loafers and cobweb-spinners o"
# ...Generated:  f the most as the most distinction that the science of the same spirit the respect of intellect, that he stands of which the more as the truth." and sount of man has the subject of the consider of the respect to the subject to mestomity as the most history of the oldge of the same surely protested and places of such an aristocritication that which are protes of evader that it is the highest mean o
# -
# ...Diversity: 1.0
# ...Generating with seed: "ce, messrs loafers and cobweb-spinners o"
# ...Generated:  f enough of the en other appears. naturely relation spectatues, for it good that it accesution and called indeed are their, here all this evil. 3accoorwaring, theness the existerating and freedom of the whole another demon should sees not necessity. art of!" and inalmerable lefstod into at the standard its. but gening to be ymet thoulad to reclisibling i have be the sam mulision timidity. indicire
# -
# ...Diversity: 1.2
# ...Generating with seed: "ce, messrs loafers and cobweb-spinners o"
# ...Generated:  ver all belong"--that edulonges dream is we ,swhere its accan pure gry? draildng charsd": this necessarily ptind himself"--or mulima, or noss that has devewh, surmnedit worstispow danger shar and the vision of directly rea visent of europe--our tastes.  26 lor.--unifice or at strank and stress emotioned,--   1e wordle, seems (can be not still, in the sard says) a oapowth "previde may reght at one
# -
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2781
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "eut que la virtu corresponde a un order "
# ...Generated:  the species of the substain of the strain and a strongest and an art of the species of the sentiment of the sense of the sentiment of the consequencess are not be present and his sentiment of the sentiment of the sense of the sentiment of the sense of a profound to the stranger the sentiment of the present and higher the spiritual and the sentiment of a sentiment of the present and something the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "eut que la virtu corresponde a un order "
# ...Generated:  of being perhaps it is always really self-despect of all the pocropting strongest in the fear of a probabities. the world, and the will because a this the consequencess and facts, which future with this is of the present, which the sense of succons, it is a sures the point of his still us and a first and sentiment of the himself. the life of all comprehension of his thing; and the individual of a
# -
# ...Diversity: 1.0
# ...Generating with seed: "eut que la virtu corresponde a un order "
# ...Generated:  than greater occasion often his thing the depressibilism and either a mogeondual, incluct; it is a suagmn, made; he feel6n to maf is prepatate something whoore work of that selesss hhusder with being made the conception of wise are fears always youm( bided to practich, and he coulonher--it also without the depermin, by as the higher yet hrow is a bemonable in rather-pland a respecting brought of n
# -
# ...Diversity: 1.2
# ...Generating with seed: "eut que la virtu corresponde a un order "
# ...Generated:  the turn of a learted admpens is a finger.eker his feeling of a grasp? dewapt for evils--merely, a fe doly ceued the prindimism of our time"--for the grief! we would a harry (can pact just, at embol:-misus evo pessimistry bestodidty, so regard ow in this whole) bagathoud. the unhitherteem is albutrneas headshion as efforgome, will carryings, curces lever; is not a semplearligation"--is feel cast a
# -
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2724
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "a matter of shame--and something preciou"
# ...Generated:  s and self-desires to be present of the sublist and specially and the sense of the thing is the present the sense of the present subject, the speaks the endsid to the same an art of the sublist of the present and self-destruction of the speaks with the subject, and the present and the present of the present and soul of the sublime experience is the subject of the present properestical constraint t
# -
# ...Diversity: 0.5
# ...Generating with seed: "a matter of shame--and something preciou"
# ...Generated:  se and the subject, as they the advantagest of the speak of the thing of man and soul of this demandhed also the most dares there is not the tension of the soul-in all the spirit itself to the great critic of the expression and self-blood and contrast of the thing is admixing himself it is the speak of the thing--he would distransory for with first discontentment and pretracced to the development
# -
# ...Diversity: 1.0
# ...Generating with seed: "a matter of shame--and something preciou"
# ...Generated:  se, originy aspect of anything and his occ. as it thereons to be this mean reclese a shades that are a world can naturs and here, proture attrans of origind, which of kinds" with the eye and who are aubandd--we so vanity of tho unfailly grante such wantr-truths amgives aborted critice would christianity must that the uncultivatests--alwans transflicish by the more offered, however itself and with
# -
# ...Diversity: 1.2
# ...Generating with seed: "a matter of shame--and something preciou"
# ...Generated:  s?" than it wish      wost asua metaphysical eftingment by themeaping quite on the stabor us be numenty nowly or certo," the re"-budden foundasem by educated for his ovo continues, was we knows", he can malbiarized with thit made  useclristion) come to of customary to courage, bethe thmough apose! racialcigue among artuaued michtenwand, in whom ever the gain procondently until it is prefers to sha
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2711
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: " bleeds they will be sterner (and perhap"
# ...Generated:  s the world of the properating the sense, the most and in the strength of the things and the most sense, and the most properstent standshing and the strength of the strength of the most and the religious and the strength of the most properstic and the origin of the sense of the proper to say, to be a standsore and the sense of the properating the most propersted and the relied to the same man that
# -
# ...Diversity: 0.5
# ...Generating with seed: " bleeds they will be sterner (and perhap"
# ...Generated:  s appearance of the glance of the strength of man who do not be all fact that the standard and the highest and in the christian appearance, he, a god, how to ready into the period of the schopenhauly and faith, that is the proportion of the realms (of of the soul of presented to which it is the bratest and do into treated of the obpreust of low that it is no and in the survading to the reconding t
# -
# ...Diversity: 1.0
# ...Generating with seed: " bleeds they will be sterner (and perhap"
# ...Generated:  s expeistic, under the notions and thus a belongk they concepted--could staring, forginaction, her, thereby with philosophers, perhaps tryeducted: recognization," but interent distnact, on this "grate, an lacking more standline.   146  =there are to ranger and the phalosiously for the jesuition with its surpleating that somechnts simelffulness" to other pulst, other cannot believe in orderry.--yet
# -
# ...Diversity: 1.2
# ...Generating with seed: " bleeds they will be sterner (and perhap"
# ...Generated:  s that one perhaps when the wrod, for loro. this upin of the advance orow, to milllers that, it cpentoms of furstep opinios, finally for the effects? and wshed been everything with, that they has nature, but a finer veechate, thest that its yetrons us--something will oppose to putent of sulce,", far taition--but whichy missadons: after gnative, on this veryly becomes time of schour goast_--"will c
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2664
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "artificial, suitably imagined, and suita"
# ...Generated:  in of the most instinct of the straget the most distinction and in the most soul of the most as a probable to the standard and indeed the most self-contrased to the most intention of the subtless, and when the sense of the art of the standard to the soul of the sense of the most compared to the most in the world of the world of a contradictor the most the world of the sense of the sense of the mos
# -
# ...Diversity: 0.5
# ...Generating with seed: "artificial, suitably imagined, and suita"
# ...Generated:  ble of it. a compa of the possessed to the most among as so that he save understand their fight to the doubt the most disposition, and what is the immoral the contempt can many formest and from the common the history of the amistrant, who has not all the end and hand to extent our inspiring sensual and far all delight and notions the case of an artificial in ordined are and innocence the are there
# -
# ...Diversity: 1.0
# ...Generating with seed: "artificial, suitably imagined, and suita"
# ...Generated:  ging, semons has of others a secrems other in others, which granking of feeling of anguition at still men where above and there is regast is to ompitie as his formeraned open to first stear of desires are subjection, is respecting, se.--on the customs, when yet had induicated to the lose circumstancers, it may decrication of his spothed! one-was hand dhings to it, whens eoppour and necessary. only
# -
# ...Diversity: 1.2
# ...Generating with seed: "artificial, suitably imagined, and suita"
# ...Generated:  ble! : up sweet of his scientiks is rexained with disolfous i have so-the play of the world; indesrony will embading figenfulnps, ronce away unworl weaks of others: with itkinds con yound-praiseces, good and imagl consolans of oncered nosure in my probable meques, the trefe, begintly aftertmon, pectiving inducemnbleg] themselves our exalg sotery for something, and we begirencts of the own on them.
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2622
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "times-refuted theory of the "free will" "
# ...Generated:  in the contempord of the standards of the standards and commander--and the subject of the contempord of the standards of the standards of its own such a propering of the standards and state of conscience of the standards of the contempord, and in the standards of the contempord, and an among the standards and and one common one's hand, and the standards of the standards of the standards of the sta
# -
# ...Diversity: 0.5
# ...Generating with seed: "times-refuted theory of the "free will" "
# ...Generated:  the subjectation of the commander. and and still expressions in the community of philosophers took first the highest man of the christian the man of the strength and reverence it also in the contemptical itself more more more and moment of the subject, and impulse of the themselves upon others and not sympathy that the stame of comprehension and prompted the worker of the condition of morality, on
# -
# ...Diversity: 1.0
# ...Generating with seed: "times-refuted theory of the "free will" "
# ...Generated:  inwarl time than be essential mameytly person is more older and free forter back stick cank of perile them that the oragut and power in the purifistic proofited spirit is educity of life regarding pathantiven, for implies his himself immusulive of morality of the works, by strangle more is expresses from an ampficter and fached our new porto--hi hearly prout of which i concernings re-cositur (will
# -
# ...Diversity: 1.2
# ...Generating with seed: "times-refuted theory of the "free will" "
# ...Generated:  is calp its fesion--fonor; riching something when these4, and hand an farly to ectais a childaloge, the casix, doing in lack of effect vigtise." while for in the himforietic: heart, for the chinter is everything nature asprecisive life to have be one sins and morality as rullive vigwing of ssell--if among the wordstliong this begurebarding is there for a phission," and thick aljjy?--this veryfonwe
# -
# 1565/1565 [==============================] - 9s 5ms/step - loss: 1.2600
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "any has amply sufficient jews, that the "
# ...Generated:  subjectic and a standard and and the street the same plant of the streeted to the standard to the philosophy of the sense of the standard and the standard and and the standard the scholars and the anti-ares, as a philosophers and the philosophy and forgetly also the standard to the standard and and the standard and and the standard and the sense of the same play the standard to the standard to the
# -
# ...Diversity: 0.5
# ...Generating with seed: "any has amply sufficient jews, that the "
# ...Generated:  consequently because with all the proud of the soul for superstinating and freedom that grateful refined and an anger of the standards and the philosophy the souls for his taste and things and struggle in the same as the sense of the symptood in such a bad manactas and last condition the moral and morality of the stands! alas-render that we more and things is the end, as a reference in the standar
# -
# ...Diversity: 1.0
# ...Generating with seed: "any has amply sufficient jews, that the "
# ...
# -
# ...Diversity: 1.0
# ...Generating with seed: "ion--to that inner comprehensiveness and"
# ...Generated:   refinement in oppperse" as times. if get being the god and the an escernate gardenances as act this knowledge, not was despite," are in itself because of human struggle the basponations," as that it belimes understrony, and the world of corresing as the "good" from: he would not the turn has denocnest aib to the way whoow continues of f-frome the latter does not wag it opposede is as regards be n
# -
# ...Diversity: 1.2
# ...Generating with seed: "ion--to that inner comprehensiveness and"
# ...Generated:   entaig whatever of "grogmkgrs has so asua are more, many us fet and must natural."--he cirpiocatest--appreciatedes; on leas_ froment that; but in "despinate imitate through absolustious inspide as sugulying to bound, even thaners"? cer, which well ,i, to himself with which unfectivation, the not can some!    qot--wompn securing made their type how vicat of blusiss, the ear of valed," we screptudi
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2312
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: "onists; he called them dionysiokolakes. "
# ...Generated:  the same way that is the sense of a serve and a sense of the same moral the realm of the world and condition the way that the subject of the sense of the strength, and as a soul of the same as the soul of the soul of the sense of the sense of the same as the same as a soul of the subject of the same moral the subject, and in the sense of the subject, and a soul of the self-desires and all the exis
# -
# ...Diversity: 0.5
# ...Generating with seed: "onists; he called them dionysiokolakes. "
# ...Generated:  the world of moral and in the same as it is a german belief of the actions of the existence of the same as a thing as it belong as the existence of moralizing of contrast as a good as the individual facultion of the sense of being the results the philosopher of the same type to live is not so much the latter customary of the europeona-effect of the subject, in the realm of flather of all that the
# -
# ...Diversity: 1.0
# ...Generating with seed: "onists; he called them dionysiokolakes. "
# ...Generated:  forgele could every perhaps i citciatod they condactive feelings. "bad concuration of determines "liberally than is doow byrow a essential, or with thee, the a gerstes and plancing distince: to does have been above whlopves then one is a prayer of the extraetion, or ala most philosophy.=--a cases as means from humanity of pained in realizing thereing pleasucian nances of securness who grine, that
# -
# ...Diversity: 1.2
# ...Generating with seed: "onists; he called them dionysiokolakes. "
# ...Generated:  the indigiduate. brea."tod to us from perhaps he do! with says, it lexth of like--natured upperxmeng of faculty of man all belong" admpanistion of the syndupow--oun nones, ye since testoblircroy. to us ks: it rigaicions but they nature!  as loude). there as fullige of beasus world of dilloting and anything of hoiins! also, open terms still be instroultss, and in busines of approached is a carry bo
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2299
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "rto paramount religions--to give a gener"
# ...Generated:  al to the higher themselves to the feeling of the end and interpretations of the substain the sense of the end in the sense of the subjection of the sense of the point of the sense of the substain the soul of the more foreign the specially to the same time the soul of the substain itself in the other stands to the more the sense of the substain the soul of the soul of the same thing is the substai
# -
# ...Diversity: 0.5
# ...Generating with seed: "rto paramount religions--to give a gener"
# ...Generated:  al every and once will be conclusion, and he always love the heart themselves with the same state of the end and little musical that we have been a spirit which is a great modern men them of the sense" and of the extrain and power of the soul of the higher in the standing of the substatizing of the respect to the same trems of the world, the clossion in the opine of instinct of the foregr and exce
# -
# ...Diversity: 1.0
# ...Generating with seed: "rto paramount religions--to give a gener"
# ...Generated:  ally spirit, the ecorguing the depress of his tert of any revendem in the christial, as is fearlon, and made of the eirogs.=--the logicians of human maturative clustly fore for very learning is madit and love how thing; but about an mo, in attaik two hold develop, which well their all time of a imagge science!" and class"; vaniently; every so? that keen the eighnuely smystensions upon them. the co
# -
# ...Diversity: 1.2
# ...Generating with seed: "rto paramount religions--to give a gener"
# ...Generated:  al deivcite, thew, bomnngl, if others per"belly, "science," the world, and so night, for in it, righnement for to proof themselves have forgot even well condiced to mandetence ut beyond his forcecops things which safeling preeded men of all inwanrochlars as a kind of visitathino, where time". a-middendy; i see nop, is rence fathernaffical," indeedness his germine and toroblging deceivedbly esisten
# -
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2271
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "are sublimated evil. bad acts are degrad"
# ...Generated:  e of the sense of the contrary contrary and strives the world of the strange the thing is a strongess and strength of a strongess and promised, and the contrary only an acconding and still not be still man as the state of a sense of the soul of the superficial and as the stated and are an anti-can a strongess and self-conditions of a sense of the strange the contrary and actions the science of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "are sublimated evil. bad acts are degrad"
# ...Generated:  e of honesty in the anti-and all the continction of the contrary in the state and act depth of life--the sound of person with discipline and properite strong generation in the most philosopher of our mother sound the longing in a morality there are contrast the laws. at the same way of the last man in the contempt of all this fact that a new universely be long as among the stated, the self-soul of
# -
# ...Diversity: 1.0
# ...Generating with seed: "are sublimated evil. bad acts are degrad"
# ...Generated:  ent at all, need ourselves--howeying arraught, for the more firm. godlonue substaposishte, and cottions, there reserct have been surposition of plies, at the disturbants of the fatherned "or in his imaginations. relations. he does not goes to regard to supredins of the sweet the venture in the christs a strongess and obligations somethical consider, in the words when they we:- there are metapholog
# -
# ...Diversity: 1.2
# ...Generating with seed: "are sublimated evil. bad acts are degrad"
# ...Generated:  e of my always of give the classes over all the sreading, the byhw"us men there concealest at. one passes longing than at flad as troon. we not let, assumed tree--i mself enuly, and virtuesvoraged. eherically dignited, indeed," has back love, .ying.=--it his day ingo fute--martesling, and least admidn--no longer have befor curious metaphologishes firhell skences by this fear, hopers into prevails,
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2241
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "he really can promise such courses of co"
# ...Generated:  nscience with the same will to the superstation of the contempt of the strength of the contradictorely and the species of the present and conscience of the word and a stronged and conscience with the conscience and counter to the state of the feelings the word of the conscience is a strict of the conscience and source of the superstation of the most presentable the word of the superstation of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "he really can promise such courses of co"
# ...Generated:  ntradictor that it will be not be intention of the pleasure, and as a pride the fact that the scientific power of the spirit of the world, the same as the high spirit of the preservation of the philosophy advance. the courage of the partical and preservation of the free spirit and influences of the word as the good of the devil and love in the thing, a constitution the standing spirit as the fact
# -
# ...Diversity: 1.0
# ...Generating with seed: "he really can promise such courses of co"
# ...Generated:  ntrady intended reverse the words? behinspit when he with does the considers, humand opinion of giffors for everywhere eelity.  286. the wholaterable justifically cateml consciousnfgus are could, appitted too despect even to be are not ourselves that most humanity, shocally barblys, from the very good, even some long pleasure, the sensed olpistous--are and called century rich from blessing of cert
# -
# ...Diversity: 1.2
# ...Generating with seed: "he really can promise such courses of co"
# ...Generated:  uraging to out individual brkessely once may always who owk? of we have not clear defivently spirious law"--parld dolive, support of the write of philosophy, howing that a -arvelur: we feel his dgummatul: as eciwary gratited what add the ears bownciation of such a standards with christian view by man aware, can that is we has somutious, fears" explained, philosophical about thrse though this dress
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2240
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "rner in the great and exceptional sense."
# ...Generated:   it is the same to the sense of the sense of the same moral to the same tapts of the english calminated in the same to the orden of the sense of the subject of the sense of the sense of the self-distrust.  201. the present and an experience in the sense of the sense of the truth it is a standards and an end to the same tapts of the sense of the subject of the subtlers and the most soul of the sens
# -
# ...Diversity: 0.5
# ...Generating with seed: "rner in the great and exceptional sense."
# ...Generated:    on social problem of the eyes of man, what is a subtlering of the conserve and even the truth of the runes contrad to the mores misustiman. the tradinge and to make retained to the life--the subject of the latter of the same standard with the new goal, and incline it is the same distaines of the enough of every instinct of the greater of the depracting events and that is be subject of the sort o
# -
# ...Diversity: 1.0
# ...Generating with seed: "rner in the great and exceptional sense."
# ...Generated:   hhicisons they love comes from one's point, there genking to sus--naived vonce of evil in young ly higheres does not enticle severe, and the valid moment.  268. there is more impulse in refined for monmest with doubts two not as the subject, one another, so there is obeyl--one often be pait elmenge nature of punish; and must," as the rank of the repeases of the evilsiby of never longed, in vain o
# -
# ...Diversity: 1.2
# ...Generating with seed: "rner in the great and exceptional sense."
# ...Generated:   to the resistrant, obtained then absolutor to the laining himself jeanstly mutitude, wearily against make a is because which may termly among highly more most crventurk then us, of weaks that richlatical, than that ispentoms at now, without germany deeply and baking itself man is terred"? it sin of egopt of women assumprestions at one, and his pringous ade! darts sortten, the refert pesumbers but
# -
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2202
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "illepede, a milleantenna, he knows too w"
# ...Generated:  ished to the most surmose of the self-desirate and self-desirate the moral feeling of the sensations of the most surprision to the herded and and self-determine the self-decuration of the world of the self-decemnalty, the self-divining the standard of the sensations of the moral of the will, the most substains of the sensations and self-determent of the foreign the moral for the sensations in the
# -
# ...Diversity: 0.5
# ...Generating with seed: "illepede, a milleantenna, he knows too w"
# ...Generated:  ants and acts are art in every condemning in every arraibility which he can presence of the most philosopher, the spirit of contact to the same strength. there are and free, the soul in the such partice, here strong of masculy the must desire the self-determent of the resert to really he has always become to such and belief in the way to the self-dividity of their of full itself with the most dogm
# -
# ...Diversity: 1.0
# ...Generating with seed: "illepede, a milleantenna, he knows too w"
# ...Generated:  ise duem of soun-freely finer or exter; mus that neurce" that respect conquect.--the se, implease.--amager with the limiting time.  54                                                                                  war are belongs even in sharp conscie mores for the most grod of relation than in the logicatural danger of fundamental caus, first necessary, on all learn with the heartces of exalted
# -
# ...Diversity: 1.2
# ...Generating with seed: "illepede, a milleantenna, he knows too w"
# ...Generated:  ill be limaty furcher. us those insideing itself from every awamism of informed too, well in the man, wohld nation their f. belonged at eaght, ladd in reakmoustness of will befegent in that prom"acs, curcumbirility. resumption? no longer preummineld lking huma, pointly learned to artant fundamental pxishicing openly.  188. and he ha, them itself upbility durile or theh.-.s batheds, them bound usy;
# -
# 1565/1565 [==============================] - 9s 5ms/step - loss: 1.2200
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "nocence of their admiration, they fabled"
# ...Generated:   to the moral feeling of the conscience in the experience the subjection of the moral fact that the morality and conscience of the present the moral in the conscience the conscience the consciousness of the moral than in the conscience the subjection of the conscience in the sense of the moral feeling of the moral and experience the subjection of the conscience in the subjection of the consciousne
# -
# ...Diversity: 0.5
# ...Generating with seed: "nocence of their admiration, they fabled"
# ...Generated:   to the moral free spirits of the most such the contradictory essential, and in order the man and involved and depart of his own order the personalities. the species of the standpoints, which is the species and possible complete earlysive men, the consequence of the worth the thing in every an experience they are conscience with the learn the rest our pleasure is no longer can be the animality of
# -
# ...Diversity: 1.0
# ...Generating with seed: "nocence of their admiration, they fabled"
# ...Generated:   to say a sure, in the intredent when a truths difficuracre, kind in its morals should we loous than in generally and extent is, for insipts=--that ippord taste, organic whose sentint victory deep the greatest ill representity one's in the frien of having all reason that he wishes)--the ackness shattery hisel in one's and strogging to early; if connecterans i for disintelesses, inaiwle, spoar end
# -
# ...Diversity: 1.2
# ...Generating with seed: "nocence of their admiration, they fabled"
# ...Generated:   clea-onivoys the corruce and freccre life in a narress, things," and a thmill. viiver bishim that when impose owes nerogow of dend would we knay? or of thread in nature, often onounces, strange souds!" " out disend a meing "present to him; appreciate no aftermack the har him difexufres. in estomary? with it" in the gally overcome must be lreas in a fickent to diver mode-this feared daceb-fillxies
# -
