# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/12YKHOXgPyXKLQV2Q2HYCceG13JMszqb-?usp=sharing)
#
# Source: https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

keras.utils.set_random_seed(0)

# This will make TensorFlow ops as deterministic as possible, but it will
# affect the overall performance, so it's not enabled by default.
# `enable_op_determinism()` is introduced in TensorFlow 2.9.
tf.config.experimental.enable_op_determinism()

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    h = 0.05
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:,0], X[:,1], c=y.ravel(), cmap=plt.cm.Spectral)

def load_planar_dataset(m, sigma=0.2):
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*sigma # theta
        r = a*np.sin(4*t) + np.random.randn(N)*sigma # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j

    ## premuting ouput
    p = np.random.permutation(m)
    X = X[p,:]
    Y = Y[p,:]

    return X, Y.ravel()

def draw_neural_net(left, right, bottom, top, layer_sizes):
    '''
    From https://gist.github.com/craffel/2d727968c3aaebd10359#file-draw_neural_net-py
    Draw a neural network cartoon using matplotilb.

    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])

    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    fig = plt.figure(figsize=(3, 3))
    ax = fig.gca()
    ax.axis('off')

    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %% [markdown]
# ## Dataset
#
# We have a binary classification dataset. The target `y` has two possible values, {0,1} and the input vector `x` has two dimensions.

# %%
N = 5000
X, y = load_planar_dataset(N, 0.2)

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.2,
)

# %%
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(4000, 2), y_train shape:(4000,)
# X_test shape:(1000, 2), y_test shape:(1000,)

# %%
## X first example
X[0,:]
# Out:
# array([ 0.34000393, -0.30416122])

# %%
## Y firsts examples
y[:8]
# Out:
# array([0, 1, 1, 0, 0, 1, 1, 1], dtype=uint8)

# %% [markdown]
# ## First NN in Keras
#
# ### Logistic regression
#
# Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class. We can specify the number of neurons as the first argument, and specify the activation function using the activation argument.
#
# ```python
# tf.keras.layers.Dense(
#     units, activation=None
# )
#
# ```
#
# - **units**: Number of neurons in the layer.
# - **activation**: Activation function to use, default function is `linear`, you can also use `sigmoid` for sigmoid activation or [other alternatives](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# For defining the input layer you can use `keras.Input(shape=(input_dimension,))` or define your input dimension in the first hidden layer.
#
# ```python
# layers.Dense(4, activation="sigmoid", input_shape=(input_dimension,))
#
# ```
#
# Build a network without hidden layer

# %%
draw_neural_net(.1, .9, .1, .9, [2, 1])

# %%
model = keras.Sequential()
# The dimension of the input is 2 (planar data)
# we have only one output layer with 1 neuron
model.add(keras.layers.Dense(1, use_bias=False, input_shape=(2, ), activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# #### Compile
# Now we need to specify the loss function, the metrics and the optimizer. It is done using compile function in Keras.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Training model
# This is similar to a sklearn model.

# %%
model.fit(X_train, y_train, epochs=10,
          validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5549 - loss: 0.9427 - val_accuracy: 0.5500 - val_loss: 0.9417
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5483 - loss: 0.8958 - val_accuracy: 0.5425 - val_loss: 0.8911
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5407 - loss: 0.8522 - val_accuracy: 0.5325 - val_loss: 0.8454
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5349 - loss: 0.8130 - val_accuracy: 0.5263 - val_loss: 0.8051
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5253 - loss: 0.7789 - val_accuracy: 0.5175 - val_loss: 0.7707
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5165 - loss: 0.7498 - val_accuracy: 0.5150 - val_loss: 0.7422
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5049 - loss: 0.7260 - val_accuracy: 0.5100 - val_loss: 0.7195
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4996 - loss: 0.7073 - val_accuracy: 0.5013 - val_loss: 0.7020
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4967 - loss: 0.6931 - val_accuracy: 0.4988 - val_loss: 0.6893
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4860 - loss: 0.6828 - val_accuracy: 0.4938 - val_loss: 0.6803

# %% [markdown]
# #### Making predictions

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.675510048866272
# Test Accuracy: 0.4749999940395355

# %%
y_pred = model.predict(X_test)
y_pred[:3], y_test[:3]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (array([[0.25868812],
#         [0.80798846],
#         [0.69198024]], dtype=float32),
#  array([0, 1, 0], dtype=uint8))

# %%
# clasification metrics
from sklearn.metrics import confusion_matrix, classification_report

y_pred_class = (y_pred > 0.5).astype('int32')

print(confusion_matrix(y_test, y_pred_class))
print(classification_report(y_test, y_pred_class))
# Out:
# [[238 283]
#  [242 237]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.46      0.48       521
#            1       0.46      0.49      0.47       479
#
#     accuracy                           0.47      1000
#    macro avg       0.48      0.48      0.47      1000
# weighted avg       0.48      0.47      0.48      1000

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("Basic NN");
# Out:
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### One hidden layer NN
#
# https://playground.tensorflow.org/
#
# - One **input with 2 features (input_shape)**
# - **One hidden dense layer**,  with **3 neurons** and implemented with  **sigmoid activating function**
# - **One Output** (sigmoid output activation function)
#
# We can create layers incrementally with the method `add()`:

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 1])

# %%
model = keras.Sequential()

## hidden layer with 3 neurons and sigmoid activation
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,)))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

## model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 3)                   │               9 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# You can also define the model with a list of layers
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2, )),
#     layers.Dense(3, activation='sigmoid', name='layer1'),
#     layers.Dense(1, activation='sigmoid', name='layer3')
# ])
# ````

# %%
plot_model(model, show_shapes=True)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5918 - loss: 0.8308 - val_accuracy: 0.5838 - val_loss: 0.7318
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5642 - loss: 0.7299 - val_accuracy: 0.5375 - val_loss: 0.6810
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5278 - loss: 0.6828 - val_accuracy: 0.4950 - val_loss: 0.6661
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4730 - loss: 0.6682 - val_accuracy: 0.4750 - val_loss: 0.6636
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4641 - loss: 0.6647 - val_accuracy: 0.4762 - val_loss: 0.6634
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4667 - loss: 0.6639 - val_accuracy: 0.4762 - val_loss: 0.6635
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4659 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6636
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4662 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6636
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4662 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4663 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4663 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4663 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4663 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4658 - loss: 0.6636 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4658 - loss: 0.6637 - val_accuracy: 0.4775 - val_loss: 0.6637

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6634964942932129
# Test Accuracy: 0.46299999952316284

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN");
# Out:
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 1:
# ####  What happens if we change the activation function of the first hidden  layer to `'linear'`?

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6078 - loss: 0.6876 - val_accuracy: 0.6575 - val_loss: 0.6878
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6436 - loss: 0.6821 - val_accuracy: 0.6687 - val_loss: 0.6825
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6534 - loss: 0.6771 - val_accuracy: 0.6712 - val_loss: 0.6776
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6608 - loss: 0.6724 - val_accuracy: 0.6737 - val_loss: 0.6731
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6695 - loss: 0.6681 - val_accuracy: 0.6762 - val_loss: 0.6691
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6742 - loss: 0.6643 - val_accuracy: 0.6762 - val_loss: 0.6655
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6800 - loss: 0.6609 - val_accuracy: 0.6800 - val_loss: 0.6624
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6850 - loss: 0.6579 - val_accuracy: 0.6812 - val_loss: 0.6597
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6839 - loss: 0.6553 - val_accuracy: 0.6812 - val_loss: 0.6570
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6771 - loss: 0.6528 - val_accuracy: 0.6737 - val_loss: 0.6544
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6732 - loss: 0.6503 - val_accuracy: 0.6712 - val_loss: 0.6515
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6712 - loss: 0.6476 - val_accuracy: 0.6687 - val_loss: 0.6482
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6709 - loss: 0.6446 - val_accuracy: 0.6675 - val_loss: 0.6446
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6641 - loss: 0.6412 - val_accuracy: 0.6625 - val_loss: 0.6406
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6623 - loss: 0.6376 - val_accuracy: 0.6575 - val_loss: 0.6364
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6568 - loss: 0.6339 - val_accuracy: 0.6525 - val_loss: 0.6321
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6534 - loss: 0.6300 - val_accuracy: 0.6475 - val_loss: 0.6279
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6529 - loss: 0.6262 - val_accuracy: 0.6450 - val_loss: 0.6238
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6512 - loss: 0.6224 - val_accuracy: 0.6438 - val_loss: 0.6199
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6489 - loss: 0.6188 - val_accuracy: 0.6413 - val_loss: 0.6161
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6464 - loss: 0.6152 - val_accuracy: 0.6400 - val_loss: 0.6125
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6467 - loss: 0.6119 - val_accuracy: 0.6400 - val_loss: 0.6091
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6466 - loss: 0.6087 - val_accuracy: 0.6400 - val_loss: 0.6059
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6460 - loss: 0.6058 - val_accuracy: 0.6400 - val_loss: 0.6030
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6453 - loss: 0.6030 - val_accuracy: 0.6375 - val_loss: 0.6002

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6067837476730347
# Test Accuracy: 0.6340000033378601
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 2:
# ####  What happens if we add more neurons to the first hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 5, 1])

# %%
model = keras.Sequential()

## The first layer need to have the input_shape
## set the number of neurons
model.add(layers.Dense(5, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5606 - loss: 0.6861 - val_accuracy: 0.6338 - val_loss: 0.6650
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6287 - loss: 0.6674 - val_accuracy: 0.6625 - val_loss: 0.6521
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6362 - loss: 0.6549 - val_accuracy: 0.6263 - val_loss: 0.6432
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5986 - loss: 0.6463 - val_accuracy: 0.5950 - val_loss: 0.6367
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5687 - loss: 0.6398 - val_accuracy: 0.5713 - val_loss: 0.6315
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5498 - loss: 0.6347 - val_accuracy: 0.5375 - val_loss: 0.6272
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5268 - loss: 0.6303 - val_accuracy: 0.5188 - val_loss: 0.6232
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5091 - loss: 0.6263 - val_accuracy: 0.5063 - val_loss: 0.6196
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4987 - loss: 0.6226 - val_accuracy: 0.5013 - val_loss: 0.6161
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4893 - loss: 0.6192 - val_accuracy: 0.4938 - val_loss: 0.6129
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4805 - loss: 0.6159 - val_accuracy: 0.4875 - val_loss: 0.6099
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4697 - loss: 0.6129 - val_accuracy: 0.4800 - val_loss: 0.6070
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4663 - loss: 0.6101 - val_accuracy: 0.4737 - val_loss: 0.6044
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4640 - loss: 0.6074 - val_accuracy: 0.4712 - val_loss: 0.6019
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4607 - loss: 0.6050 - val_accuracy: 0.4737 - val_loss: 0.5996
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4635 - loss: 0.6028 - val_accuracy: 0.4775 - val_loss: 0.5975
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4664 - loss: 0.6007 - val_accuracy: 0.4812 - val_loss: 0.5956
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4715 - loss: 0.5988 - val_accuracy: 0.4837 - val_loss: 0.5938
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4742 - loss: 0.5971 - val_accuracy: 0.4850 - val_loss: 0.5921
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4786 - loss: 0.5955 - val_accuracy: 0.4900 - val_loss: 0.5906
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4834 - loss: 0.5940 - val_accuracy: 0.4925 - val_loss: 0.5891
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4869 - loss: 0.5926 - val_accuracy: 0.4938 - val_loss: 0.5878
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4961 - loss: 0.5914 - val_accuracy: 0.5025 - val_loss: 0.5866
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5023 - loss: 0.5902 - val_accuracy: 0.5113 - val_loss: 0.5855
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5068 - loss: 0.5891 - val_accuracy: 0.5200 - val_loss: 0.5845

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5892279148101807
# Test Accuracy: 0.5019999742507935
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 3:
# ####  What happens if we add one more hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 3, 1])

# %%
model = keras.Sequential()
# First hidden layer (need to innclude input_shape)
## Set the number of neurons
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# second hidden layer
## Complete the code
model.add(layers.Dense(3, activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 3)                   │               9 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 3)                   │              12 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25 (100.00 B)
#  Trainable params: 25 (100.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5153 - loss: 0.6972 - val_accuracy: 0.5088 - val_loss: 0.6941
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5173 - loss: 0.6914 - val_accuracy: 0.5412 - val_loss: 0.6905
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5662 - loss: 0.6889 - val_accuracy: 0.6350 - val_loss: 0.6874
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6443 - loss: 0.6863 - val_accuracy: 0.6413 - val_loss: 0.6841
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6389 - loss: 0.6832 - val_accuracy: 0.5962 - val_loss: 0.6804
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6045 - loss: 0.6797 - val_accuracy: 0.5550 - val_loss: 0.6764
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5643 - loss: 0.6758 - val_accuracy: 0.5550 - val_loss: 0.6720
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5545 - loss: 0.6715 - val_accuracy: 0.5525 - val_loss: 0.6674
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5524 - loss: 0.6670 - val_accuracy: 0.5537 - val_loss: 0.6625
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5522 - loss: 0.6623 - val_accuracy: 0.5512 - val_loss: 0.6575
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5523 - loss: 0.6573 - val_accuracy: 0.5525 - val_loss: 0.6523
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5496 - loss: 0.6522 - val_accuracy: 0.5462 - val_loss: 0.6470
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5496 - loss: 0.6470 - val_accuracy: 0.5462 - val_loss: 0.6418
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5579 - loss: 0.6419 - val_accuracy: 0.5537 - val_loss: 0.6366
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5631 - loss: 0.6368 - val_accuracy: 0.5775 - val_loss: 0.6315
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5751 - loss: 0.6318 - val_accuracy: 0.5800 - val_loss: 0.6267
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5839 - loss: 0.6271 - val_accuracy: 0.5825 - val_loss: 0.6220
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5919 - loss: 0.6226 - val_accuracy: 0.5850 - val_loss: 0.6176
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5976 - loss: 0.6183 - val_accuracy: 0.5913 - val_loss: 0.6135
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6025 - loss: 0.6143 - val_accuracy: 0.5962 - val_loss: 0.6096
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6057 - loss: 0.6105 - val_accuracy: 0.5975 - val_loss: 0.6060
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6064 - loss: 0.6071 - val_accuracy: 0.6000 - val_loss: 0.6027
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6091 - loss: 0.6038 - val_accuracy: 0.6000 - val_loss: 0.5996
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6103 - loss: 0.6009 - val_accuracy: 0.6000 - val_loss: 0.5967
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6105 - loss: 0.5981 - val_accuracy: 0.6000 - val_loss: 0.5940

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5992260575294495
# Test Accuracy: 0.6039999723434448
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %% [markdown]
# ####  Use  the [hyperbolic tangent](https://mathworld.wolfram.com/HyperbolicTangent.html) activation `'tanh'` with the first simple model and compare the results with the sigmoid activation

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(10, input_shape=(2,), activation='tanh'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3833 - loss: 0.7349 - val_accuracy: 0.6700 - val_loss: 0.6458
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6631 - loss: 0.6383 - val_accuracy: 0.6525 - val_loss: 0.5936
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6412 - loss: 0.5931 - val_accuracy: 0.7150 - val_loss: 0.5617
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7210 - loss: 0.5627 - val_accuracy: 0.7650 - val_loss: 0.5366
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7754 - loss: 0.5379 - val_accuracy: 0.7912 - val_loss: 0.5137
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8017 - loss: 0.5151 - val_accuracy: 0.8112 - val_loss: 0.4918
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8126 - loss: 0.4934 - val_accuracy: 0.8263 - val_loss: 0.4712
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8291 - loss: 0.4732 - val_accuracy: 0.8375 - val_loss: 0.4522
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8443 - loss: 0.4548 - val_accuracy: 0.8487 - val_loss: 0.4352
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8550 - loss: 0.4382 - val_accuracy: 0.8600 - val_loss: 0.4200
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8623 - loss: 0.4235 - val_accuracy: 0.8675 - val_loss: 0.4066
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8711 - loss: 0.4104 - val_accuracy: 0.8800 - val_loss: 0.3948
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8808 - loss: 0.3988 - val_accuracy: 0.8863 - val_loss: 0.3843
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8892 - loss: 0.3885 - val_accuracy: 0.9050 - val_loss: 0.3750
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8989 - loss: 0.3794 - val_accuracy: 0.8988 - val_loss: 0.3668
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9066 - loss: 0.3712 - val_accuracy: 0.9013 - val_loss: 0.3594
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9088 - loss: 0.3639 - val_accuracy: 0.9013 - val_loss: 0.3528
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9088 - loss: 0.3572 - val_accuracy: 0.8975 - val_loss: 0.3469
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9041 - loss: 0.3512 - val_accuracy: 0.8900 - val_loss: 0.3416
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8992 - loss: 0.3458 - val_accuracy: 0.8900 - val_loss: 0.3367
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8985 - loss: 0.3408 - val_accuracy: 0.8925 - val_loss: 0.3323
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8968 - loss: 0.3363 - val_accuracy: 0.8925 - val_loss: 0.3282
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8974 - loss: 0.3321 - val_accuracy: 0.8950 - val_loss: 0.3245
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8976 - loss: 0.3282 - val_accuracy: 0.8975 - val_loss: 0.3211
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8962 - loss: 0.3246 - val_accuracy: 0.9000 - val_loss: 0.3179

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.3201577663421631
# Test Accuracy: 0.8870000243186951
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ## Practice I
#
# Repeat the process with a different dataset.

# %%
N = 5000
X, y = sklearn.datasets.make_moons(n_samples=N, noise=.18)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(16, input_shape=(2,), activation='tanh'))
model.add(layers.Dense(16, activation='tanh'))

## output layer
model.add(layers.Dense(1, activation='sigmoid'))


# ## Second Layer, don't use input_shape
# model.add(...)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                     │ (None, 16)                  │              48 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 337 (1.32 KB)
#  Trainable params: 337 (1.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6002 - loss: 0.6089 - val_accuracy: 0.8280 - val_loss: 0.3726
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8452 - loss: 0.3313 - val_accuracy: 0.8560 - val_loss: 0.3217
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8708 - loss: 0.2897 - val_accuracy: 0.8627 - val_loss: 0.3099
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8822 - loss: 0.2786 - val_accuracy: 0.8627 - val_loss: 0.3081
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8862 - loss: 0.2759 - val_accuracy: 0.8653 - val_loss: 0.3077
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8893 - loss: 0.2749 - val_accuracy: 0.8653 - val_loss: 0.3072
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8896 - loss: 0.2741 - val_accuracy: 0.8653 - val_loss: 0.3065
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8898 - loss: 0.2734 - val_accuracy: 0.8653 - val_loss: 0.3057
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8899 - loss: 0.2726 - val_accuracy: 0.8653 - val_loss: 0.3049
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - loss: 0.2717 - val_accuracy: 0.8653 - val_loss: 0.3039
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8907 - loss: 0.2708 - val_accuracy: 0.8653 - val_loss: 0.3029
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8905 - loss: 0.2697 - val_accuracy: 0.8653 - val_loss: 0.3017
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8900 - loss: 0.2686 - val_accuracy: 0.8653 - val_loss: 0.3004
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8886 - loss: 0.2672 - val_accuracy: 0.8653 - val_loss: 0.2988
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8892 - loss: 0.2656 - val_accuracy: 0.8667 - val_loss: 0.2969
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8896 - loss: 0.2636 - val_accuracy: 0.8667 - val_loss: 0.2945
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8902 - loss: 0.2611 - val_accuracy: 0.8667 - val_loss: 0.2915
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - loss: 0.2580 - val_accuracy: 0.8707 - val_loss: 0.2876
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - loss: 0.2541 - val_accuracy: 0.8760 - val_loss: 0.2825
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8917 - loss: 0.2490 - val_accuracy: 0.8773 - val_loss: 0.2759

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.2558460831642151
# Test Accuracy: 0.8823999762535095
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Functional API
#
# The Keras Functional API allows defining the topology of the models as a [acyclic directed graph](https://en.wikipedia.org/wiki/Directed_acyclic_graph) of layers. Next we will build the same model as in the previous section but using the Keras Functional API.
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
# ```
#
# We define the layers that we will include in the network and the relationships between them. It is important to note that each line details the type of layer and its properties (number of neurons, activation function, name ...) and just at the end, in parentheses, the name of the variable in which we have saved the layer from which its output will connect to the input of the layer we are declaring.
# ```python
# layer_1 = layers.Dense(4, activation='sigmoid',
#                        name='layer_1')(inputs)
# layer_2 = layers.Dense(4, activation='sigmoid',
#                        name='layer_2')(layer_1)
# ```
#
# The "layer call" `Dense()(inputs)` action is like drawing an arrow from "inputs" to this layer you created. You're "passing" the inputs to the dense layer, and you get `layer_1` as the output.
#
#
#
# Finally, we define the network outputs:
# ```python
# outputs = layers.Dense(1, name='output_layer')(layer_2)
# ```
#
# We create the model specifying the inputs and outputs:
# ```python
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```

# %%
draw_neural_net(.1, .9, .1, .9, [8, 4, 4, 1])

# %%
inputs = keras.Input(shape=(8, ), name='input_layer')
l_1 = layers.Dense(4, activation='relu', name='layer_1')(inputs)
l_2 = layers.Dense(4, activation='relu', name='layer_2')(l_1)
outputs = layers.Dense(1, activation="sigmoid", name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()
# Out:
# Model: "example_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_2 (Dense)                      │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_layer (Dense)                 │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Practice II
#
# Repeat the process with a different dataset and the **Functional API**

# %%
N = 5000
X, y = sklearn.datasets.make_circles(n_samples=N, factor=.65, noise=.065) # sklearn.datasets.make_moons(n_samples=N, noise=.15)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))

# %% [markdown]
# ### Define your model

# %%
inputs = keras.Input(shape=(2, ), name='input_layer')
## First hidden layer
l_1 = layers.Dense(...)(inputs)
...

## output layer
outputs = layers.Dense(...


model = keras.Model(inputs=inputs,...

# %%
model.summary()

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)

# %% [markdown]
# ## Visualize decision boundary by epoch

# %%
from sklearn.preprocessing import StandardScaler
from IPython.display import Image
import os

# %%
def plot_save_decision_boundary(model, X, y, epoch, epoch_image):
    h = 0.1
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    X_grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(X_grid)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.5, colors=['blue', 'red'], levels=[-0.5, 0.5, 1.5])
    plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0', alpha=0.5)
    plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1', alpha=0.5)
    plt.title(f'Epoch {epoch}')
    plt.savefig(epoch_image)
    plt.close()

def generate_spiral_dataset(n_points, noise=0.5):
    n = np.sqrt(np.random.rand(n_points, 1)) * 780 * (2 * np.pi) / 360
    d1x = -np.cos(n) * n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n) * n + np.random.rand(n_points, 1) * noise

    X, y = (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))))
    return X, y.reshape(-1, 1)

n_points = 2500
X, y = generate_spiral_dataset(n_points)

# %%
plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0')
plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1')
plt.legend()
plt.show()

# %%
# Normalize data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Create the first model
model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Create the second model
model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Create the third model
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Store the models in a list
model_list = [model1, model2, model3]

# Lets do some experimentation with different learning rates
model_list[0].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_list[1].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_list[2].compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

n_epochs = 60
epoch_images = {0: [], 1: [], 2: []}

for epoch in range(n_epochs):
    for ix in range(len(model_list)):
      model_list[ix].fit(X_train, y_train, epochs=1, verbose=0)
      epoch_image = f'epoch_{epoch}_model_{ix}.png'
      epoch_images[ix].append(epoch_image)

      plot_save_decision_boundary(model_list[ix], X_test, y_test, epoch, epoch_image)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from PIL import Image as Image_PIL

# Create the GIF

for ix in range(len(model_list)):
  gif_filename = f'epoch_animation_model_{ix}.gif'
  images = [Image_PIL.open(epoch_image) for epoch_image in epoch_images[ix]]

  duration = 0.15
  images[0].save(gif_filename,
              format='GIF',
              append_images=images[1:],
              save_all=True,
              duration=duration*1000,
              loop=0)

  # Delete the individual epoch images
  for epoch_image in epoch_images[ix]:
      os.remove(epoch_image)

# %%
# Model with LR=0.0001
Image(filename='epoch_animation_model_0.gif')

# %%
# Model with LR=0.01
Image(filename='epoch_animation_model_1.gif')

# %%
# Model with LR=0.1
Image(filename='epoch_animation_model_2.gif')

# %%
Ñ
