# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1GQVYl0Jg9ZwUzw0RMSeqxzXVCjnpDlxs?usp=sharing)
#
# Source: https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Regression_tuner.ipynb

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
tf.keras.utils.set_random_seed(0)

# %% [markdown]
# # Abalone Dataset
#
# Abalones are marine snails that can be found along coasts of almost every continent.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/AbaloneInside.jpg/440px-AbaloneInside.jpg" alt="abalone" border="0" width="400" height="500">
#
#
#
# In this notebook we are going to Predict the age of abalone from physical measurements. [Link to documentation](https://archive.ics.uci.edu/ml/datasets/abalone).

# %%
df_train = pd.read_csv(
    "https://storage.googleapis.com/download.tensorflow.org/data/abalone_train.csv",
    names=["Length", "Diameter", "Height", "Whole weight", "Shucked weight",
           "Viscera weight", "Shell weight", "Age"])
df_train.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.435     0.335   0.110         0.334          0.1355          0.0775
# 1   0.585     0.450   0.125         0.874          0.3545          0.2075
# 2   0.655     0.510   0.160         1.092          0.3960          0.2825
# 3   0.545     0.425   0.125         0.768          0.2940          0.1495
# 4   0.545     0.420   0.130         0.879          0.3740          0.1695
#
#    Shell weight  Age
# 0        0.0965    7
# 1        0.2250    6
# 2        0.3700   14
# 3        0.2600   16
# 4        0.2300   13

# %%
df_train.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  3320.000000  3320.000000  3320.000000   3320.000000     3320.000000
# mean      0.522693     0.406575     0.139271      0.824734        0.357705
# std       0.121164     0.100120     0.042708      0.491182        0.222223
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.345000     0.115000      0.436375        0.181500
# 50%       0.540000     0.425000     0.140000      0.795250        0.335500
# 75%       0.615000     0.480000     0.165000      1.150000        0.504500
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     3320.000000   3320.000000  3320.000000
# mean         0.180162      0.237921     9.896988
# std          0.110182      0.140261     3.205654
# min          0.000500      0.001500     1.000000
# 25%          0.092000      0.127375     8.000000
# 50%          0.170750      0.230000     9.000000
# 75%          0.253125      0.325000    11.000000
# max          0.760000      1.005000    27.000000

# %%
y_train = df_train.pop('Age')
X_train = df_train.copy()

# %%
df_test = pd.read_csv(
    "https://storage.googleapis.com/download.tensorflow.org/data/abalone_test.csv",
    names=["Length", "Diameter", "Height", "Whole weight", "Shucked weight",
           "Viscera weight", "Shell weight", "Age"])
y_test = df_test.pop('Age')
X_test = df_test.copy()

# %%
print(f'X_train shape: {X_train.shape}, X_test shape: {X_test.shape}')
# Out:
# X_train shape: (3320, 7), X_test shape: (850, 7)

# %% [markdown]
# ## Regression Losses
#
# - **Mean Squared Error (MSE)**:
#
# ```python
# tf.keras.losses.MSE
# ```
# ```python
# model.compile(loss='mse') or model.compile(loss=tf.keras.losses.MSE)
# ```
#
# $$ \mathrm{MSE} = \frac{\sum_{i=1}^n\left( y_i - \hat{y_i}\right)^2}{n}$$
#
#
# - **Mean Absolute Error (MAE)**:
#
# ```python
# tf.keras.losses.MAE
# ```
# ```python
# model.compile(loss='mae') or model.compile(loss=tf.keras.losses.MAE)
# ```
#
# $$ \mathrm{MAE} = \frac{\sum_{i=1}^n\left| y_i - \hat{y_i}\right|}{n}$$

# %% [markdown]
# ## Question 1: Create a sequential net with at least 1 hidden layer

# %%
model = keras.Sequential()

model.add(layers.Dense(10, input_shape=(7,), activation='relu'))

# output layer
model.add(layers.Dense(1, activation="relu"))

## model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                80
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss="mse",
    metrics=["mae"]
)
model.fit(X_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 83/83 [==============================] - 3s 5ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 7/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 8/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 9/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 10/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 11/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 12/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 13/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 18/50
# 83/83 [==============================] - 0s 4ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 26/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 108.2790 - mae: 9.9002 - val_loss: 108.0015 - val_mae: 9.8840

# %%
results = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
# Out:
# 27/27 [==============================] - 0s 3ms/step - loss: 112.3318 - mae: 10.0753
# Test Loss: 112.3317642211914

# %% [markdown]
# ## Question 2: Normalize the inputs and train the same model

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)
print('X_train mu, sigma', X_train_norm.mean(0), X_train_norm.std(0))
print('X_test mu, sigma', X_test_norm.mean(0), X_test_norm.std(0))
# Out:
# X_train mu, sigma [ 2.77689518e-16  4.65491099e-17  2.50402109e-16 -2.81434849e-16
#   2.18299274e-16  1.77100637e-16 -1.05404306e-16] [1. 1. 1. 1. 1. 1. 1.]
# X_test mu, sigma [0.05808422 0.06917445 0.03098307 0.04461505 0.04160742 0.02421514
#  0.03516632] [0.95187926 0.95135017 0.89294094 0.99223632 0.99454932 0.97495047
#  0.96304109]

# %%
model = keras.Sequential()

model.add(layers.Dense(10, input_shape=(7,), activation='relu'))

# output layer
model.add(layers.Dense(1, activation="linear"))
## model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                80
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.MSE,
    metrics=['mae']
)
model.fit(X_train_norm, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 83/83 [==============================] - 1s 4ms/step - loss: 88.0497 - mae: 8.8627 - val_loss: 77.0283 - val_mae: 8.1795
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 68.4848 - mae: 7.5502 - val_loss: 58.6559 - val_mae: 6.8220
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 53.1159 - mae: 6.3601 - val_loss: 45.2955 - val_mae: 5.7337
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 42.9229 - mae: 5.4956 - val_loss: 37.3127 - val_mae: 5.1061
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.5126 - mae: 1.6948 - val_loss: 5.5531 - val_mae: 1.7207
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.4321 - mae: 1.6900 - val_loss: 5.4830 - val_mae: 1.7188
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.3504 - mae: 1.6811 - val_loss: 5.4275 - val_mae: 1.7025
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.2833 - mae: 1.6760 - val_loss: 5.3812 - val_mae: 1.6893
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.2149 - mae: 1.6611 - val_loss: 5.3464 - val_mae: 1.6789
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.1567 - mae: 1.6589 - val_loss: 5.2993 - val_mae: 1.6705
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.0954 - mae: 1.6471 - val_loss: 5.2527 - val_mae: 1.6689
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 5.0420 - mae: 1.6443 - val_loss: 5.2273 - val_mae: 1.6586
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.9974 - mae: 1.6392 - val_loss: 5.1887 - val_mae: 1.6514
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.9470 - mae: 1.6244 - val_loss: 5.1476 - val_mae: 1.6531
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.9127 - mae: 1.6310 - val_loss: 5.1175 - val_mae: 1.6451
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.8692 - mae: 1.6194 - val_loss: 5.0894 - val_mae: 1.6368
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.8373 - mae: 1.6166 - val_loss: 5.0731 - val_mae: 1.6282
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.8119 - mae: 1.6128 - val_loss: 5.0363 - val_mae: 1.6291
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.7736 - mae: 1.6016 - val_loss: 5.0070 - val_mae: 1.6262
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.7492 - mae: 1.6005 - val_loss: 5.0298 - val_mae: 1.6234
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.7226 - mae: 1.5993 - val_loss: 4.9579 - val_mae: 1.6182
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.6961 - mae: 1.5992 - val_loss: 4.9500 - val_mae: 1.6081
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.6732 - mae: 1.5875 - val_loss: 4.9348 - val_mae: 1.6072
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.6617 - mae: 1.5884 - val_loss: 4.9145 - val_mae: 1.6216
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.6363 - mae: 1.5887 - val_loss: 4.8955 - val_mae: 1.6009
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.6169 - mae: 1.5823 - val_loss: 4.8750 - val_mae: 1.6049
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.5977 - mae: 1.5831 - val_loss: 4.8616 - val_mae: 1.6012
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.5783 - mae: 1.5746 - val_loss: 4.8467 - val_mae: 1.5999
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 4.5705 - mae: 1.5755 - val_loss: 4.8345 - val_mae: 1.6047

# %%
results = model.evaluate(X_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
# Out:
# 27/27 [==============================] - 0s 2ms/step - loss: 5.3921 - mae: 1.6268
# Test Loss: 5.392117023468018

# %% [markdown]
# ## Optimizers:
#
# - [SGD](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD): Gradient descent with momentum
# ```python
# tf.keras.optimizers.SGD(
#     learning_rate=0.01, momentum=0.0, nesterov=False, name='SGD', **kwargs
# )
# ```
# If momentum is 0:
# ```python
# w = w - learning_rate * gradient
# ```
# If we have momentum:
#
#  ```python
# velocity = momentum * velocity - learning_rate * g
# w = w + velocity
# ```
#
#
# - [RMSprop](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/RMSprop): Root Mean Square Propagation
# ```python
# tf.keras.optimizers.RMSprop(
#     learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-07, centered=False,
#     name='RMSprop', **kwargs
# )
# ```
# - [Adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam): Adaptive Moment Estimation,  is an update to the RMSProp algorithm
# ```python
# tf.keras.optimizers.Adam(
#     learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
#     name='Adam', **kwargs
# )
# ```
#
# ```python
# model.compile(loss='mse', optimizer='adam')
# model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
# ```

# %% [markdown]
# ## Question 3: Train the same model with different optimizers

# %%
model = keras.Sequential()

model.add(layers.Dense(10, input_shape=(7,), activation='relu'))

# output layer
model.add(layers.Dense(1, activation="linear"))
## model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 10)                80
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.0001),
    loss="mse",
    metrics=["mae"]
)
model.fit(X_train_norm, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 83/83 [==============================] - 1s 5ms/step - loss: 105.4490 - mae: 9.7042 - val_loss: 99.0249 - val_mae: 9.3737
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 94.1311 - mae: 9.1242 - val_loss: 88.1354 - val_mae: 8.7954
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 83.7051 - mae: 8.5507 - val_loss: 78.0688 - val_mae: 8.2204
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 73.8943 - mae: 7.9719 - val_loss: 68.3035 - val_mae: 7.6156
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 64.2431 - mae: 7.3463 - val_loss: 58.7343 - val_mae: 6.9608
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 55.0627 - mae: 6.6901 - val_loss: 49.8866 - val_mae: 6.2873
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 46.9606 - mae: 6.0331 - val_loss: 42.4001 - val_mae: 5.6441
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 40.4066 - mae: 5.4460 - val_loss: 36.5528 - val_mae: 5.1022
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 35.4446 - mae: 4.9802 - val_loss: 32.2167 - val_mae: 4.7245
# Epoch 10/50
# 83/83 [==============================] - 0s 4ms/step - loss: 31.8250 - mae: 4.6374 - val_loss: 29.0688 - val_mae: 4.4496
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 29.1699 - mae: 4.3832 - val_loss: 26.7341 - val_mae: 4.2397
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 27.1389 - mae: 4.1889 - val_loss: 24.9382 - val_mae: 4.0811
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 8.3708 - mae: 1.9748 - val_loss: 7.8207 - val_mae: 2.0051
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 8.0860 - mae: 1.9404 - val_loss: 7.5626 - val_mae: 1.9738
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 7.8369 - mae: 1.9120 - val_loss: 7.3378 - val_mae: 1.9472
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 7.6186 - mae: 1.8893 - val_loss: 7.1445 - val_mae: 1.9265
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 7.4272 - mae: 1.8692 - val_loss: 6.9784 - val_mae: 1.9081
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 7.2580 - mae: 1.8510 - val_loss: 6.8304 - val_mae: 1.8923
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 7.1088 - mae: 1.8353 - val_loss: 6.7005 - val_mae: 1.8788
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.9765 - mae: 1.8242 - val_loss: 6.5865 - val_mae: 1.8675
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.8559 - mae: 1.8141 - val_loss: 6.4870 - val_mae: 1.8567
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.7470 - mae: 1.8042 - val_loss: 6.3972 - val_mae: 1.8464
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.6491 - mae: 1.7945 - val_loss: 6.3175 - val_mae: 1.8376
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.5596 - mae: 1.7859 - val_loss: 6.2465 - val_mae: 1.8299
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.4780 - mae: 1.7811 - val_loss: 6.1841 - val_mae: 1.8225
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.4036 - mae: 1.7732 - val_loss: 6.1274 - val_mae: 1.8162
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.3346 - mae: 1.7692 - val_loss: 6.0758 - val_mae: 1.8104
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.2721 - mae: 1.7644 - val_loss: 6.0294 - val_mae: 1.8045
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 6.2136 - mae: 1.7585 - val_loss: 5.9874 - val_mae: 1.7991

# %%
results = model.evaluate(X_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
# Out:
# 27/27 [==============================] - 0s 2ms/step - loss: 6.5541 - mae: 1.7848
# Test Loss: 6.554086208343506

# %% [markdown]
# # Practice 1: Improve the model to get MAE <= 1.55 in test

# %%
# Your code here

model = ...

# %%
model.compile(
    optimizer=...,
    loss=...,
    metrics=['mae']
)

history = model.fit(X_train_norm, y_train, batch_size=..., epochs=..., validation_split=0.15)

# %%
results = model.evaluate(X_test_norm, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
